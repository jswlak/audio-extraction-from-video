# %% [markdown]
# <a href="https://colab.research.google.com/github/jswlak/audio-extraction-from-video/blob/main/smoking_overlay_with_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
# Out:
# Hi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.189)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# ## Load model
#
# ### Subtask:
# Load the YOLO model from the provided path `/content/best.pt`.

# %% [markdown]
# **Reasoning**:
# Import the YOLO class and load the model from the specified path.

# %%
from ultralytics import YOLO

# Load the YOLOv8x-oiv7 model
model = YOLO('/content/best.pt')

# %%
# Define the path to your video file
video_path = '/content/wildlife_video.MOV' # Use the correct path to your video

# Perform inference on the video using the loaded model
# The model() call will return a list of result objects, one for each frame
video_results = model(video_path)

# Save the video with detections
# The save() method on the results object will save the processed video
save_dir = '/content/video_output_with_detections' # Directory to save the output video
video_results[0].save_video(save_dir) # Save the video

print(f"Processed video saved to: {save_dir}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4283007597.py in <cell line: 0>()
#       4 # Perform inference on the video using the loaded model
#       5 # The model() call will return a list of result objects, one for each frame
# ----> 6 video_results = model(video_path)
#       7
#       8 # Save the video with detections
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     183             ...     print(f"Detected {len(r)} objects in image")
#     184         """
# --> 185         return self.predict(source, stream, **kwargs)
#     186
#     187     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     553         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554             self.predictor.set_prompts(prompts)
# --> 555         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     556
#     557     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     225             return self.stream_inference(source, model, *args, **kwargs)
#     226         else:
# --> 227             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     228
#     229     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      36             # Issuing `None` to a generator fires it up
#      37             with ctx_factory():
# ---> 38                 response = gen.send(None)
#      39
#      40             while True:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     298         with self._lock:  # for thread-safe inference
#     299             # Setup source every time predict is called
# --> 300             self.setup_source(source if source is not None else self.args.source)
#     301
#     302             # Check if save_dir/ label file exists
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/classify/predict.py in setup_source(self, source)
#      53     def setup_source(self, source):
#      54         """Set up source and inference mode and classify transforms."""
# ---> 55         super().setup_source(source)
#      56         updated = (
#      57             self.model.model.transforms.transforms[0].size != max(self.imgsz)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in setup_source(self, source)
#     257         """
#     258         self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
# --> 259         self.dataset = load_inference_source(
#     260             source=source,
#     261             batch=self.args.batch,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/build.py in load_inference_source(source, batch, vid_stride, buffer, channels)
#     298         dataset = LoadPilAndNumpy(source, channels=channels)
#     299     else:
# --> 300         dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     301
#     302     # Attach source types to the dataset
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/loaders.py in __init__(self, path, batch, vid_stride, channels)
#     393         self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR  # grayscale or RGB
#     394         if any(videos):
# --> 395             self._new_video(videos[0])  # new video
#     396         else:
#     397             self.cap = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/loaders.py in _new_video(self, path)
#     480         self.fps = int(self.cap.get(cv2.CAP_PROP_FPS))
#     481         if not self.cap.isOpened():
# --> 482             raise FileNotFoundError(f"Failed to open video {path}")
#     483         self.frames = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT) / self.vid_stride)
#     484
#
# FileNotFoundError: Failed to open video /content/wildlife_video.MOV

# %% [markdown]
# **Reasoning**:
# Use the loaded YOLO model to perform inference on a test image and store the results.

# %%
from ultralytics import YOLO
import cv2
import os

# Load the model (assuming 'model' variable is already loaded in a previous cell,
# or you can load it here if needed)
# Example: model = YOLO("best.pt") # Uncomment and modify if you need to load the model here

# Define the path to your video file
video_path = '/content/wildlife_video.MOV' # Use the correct path to your video

# Create output folder if it doesn't exist
output_folder = "output_videos"
os.makedirs(output_folder, exist_ok=True)
output_path = os.path.join(output_folder, "output_video_with_detections.mp4")


# Open video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"❌ Error: Could not open video at {video_path}")
    exit()

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # You can try other codecs like 'XVID' if 'mp4v' doesn't work
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

if not out.isOpened():
    print(f"❌ Error: Could not create VideoWriter for {output_path}. Make sure you have the necessary codecs installed.")
    cap.release()
    exit()

print(f"▶️ Processing video: {video_path}")

# --- Frame Processing Loop ---
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run detection
    results = model(frame)

    # Draw bounding boxes and labels on the frame
    # The plot() method of the Results object can do this
    annotated_frame = results[0].plot() # results is a list of Results objects, one per frame

    # Write the annotated frame to the output video
    out.write(annotated_frame)

cap.release()
out.release()
print(f"🎉 Done! Saved processed video -> {output_path}")
# Out:
# ❌ Error: Could not open video at /content/wildlife_video.MOV
# ❌ Error: Could not create VideoWriter for output_videos/output_video_with_detections.mp4. Make sure you have the necessary codecs installed.
# ▶️ Processing video: /content/wildlife_video.MOV
# 🎉 Done! Saved processed video -> output_videos/output_video_with_detections.mp4

# %%
from ultralytics import YOLO
import cv2
import os

# Load the model
model = YOLO("smoke_detect.pt")

# Paths
input_video = "input.mp4"   # input video path
output_folder = "output_videos"
overlay_icon_path = "no_smoking.png"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Load the no smoking icon
icon = cv2.imread(overlay_icon_path, cv2.IMREAD_UNCHANGED)
if icon is None:
    raise FileNotFoundError(f"❌ Could not load overlay image: {overlay_icon_path}")

# Resize icon if needed
scale_percent = 15
w = int(icon.shape[1] * scale_percent / 100)
h = int(icon.shape[0] * scale_percent / 100)
icon = cv2.resize(icon, (w, h))

# Open video
cap = cv2.VideoCapture(input_video)
if not cap.isOpened():
    print("❌ Error: Could not open video.")
    exit()

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Try multiple codecs automatically
codecs = [
    ('mp4v', 'final_output.mp4'),
    ('XVID', 'final_output.avi'),
    ('MJPG', 'final_output.avi')
]

out = None
output_path = None

for codec, filename in codecs:
    fourcc = cv2.VideoWriter_fourcc(*codec)
    candidate_path = os.path.join(output_folder, filename)
    out = cv2.VideoWriter(candidate_path, fourcc, fps, (width, height))
    if out.isOpened():
        output_path = candidate_path
        print(f"✅ Using codec {codec}, saving to {output_path}")
        break
    else:
        print(f"⚠️ Codec {codec} failed, trying next...")

if out is None or not out.isOpened():
    print("❌ Error: Could not open any VideoWriter. Exiting.")
    cap.release()
    exit()

print("▶️ Processing video...")

# --- Overlay persistence settings ---
OVERLAY_DURATION = 3  # seconds
overlay_frames = OVERLAY_DURATION * fps
overlay_counter = 0

# --- False positive suppression ---
CONF_THRESHOLD = 0.5       # confidence threshold (0.5–0.7 recommended)
# REQUIRED_FRAMES = 10        # must detect in N consecutive frames

# Require detection to persist for X seconds before confirming
PERSISTENCE_SEC = 0.3    # adjust this (0.5 sec, 1 sec, etc.)
REQUIRED_FRAMES = int(PERSISTENCE_SEC * fps)

consecutive_hits = 0

# --- Frame Processing Loop ---
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run detection with confidence threshold
    results = model(frame, conf=CONF_THRESHOLD)
    smoking_detected = any(len(r.boxes) > 0 for r in results)

    if smoking_detected:
        consecutive_hits += 1
    else:
        consecutive_hits = 0

    # Only trigger overlay if sustained for N frames
    if consecutive_hits >= REQUIRED_FRAMES:
        overlay_counter = overlay_frames
        consecutive_hits = 0  # reset so it needs to confirm again

    # Decrease counter if active
    if overlay_counter > 0:
        overlay_counter -= 1

        # Overlay icon at bottom-left
        x_offset = 20
        y_offset = frame.shape[0] - h - 20

        if icon.shape[2] == 4:  # alpha channel
            alpha_s = icon[:, :, 3] / 255.0
            alpha_l = 1.0 - alpha_s
            for c in range(0, 3):
                frame[y_offset:y_offset+h, x_offset:x_offset+w, c] = (
                    alpha_s * icon[:, :, c] +
                    alpha_l * frame[y_offset:y_offset+h, x_offset:x_offset+w, c]
                )
        else:
            frame[y_offset:y_offset+h, x_offset:x_offset+w] = icon

    # Write frame to output
    out.write(frame)

cap.release()
out.release()
print(f"🎉 Done! Saved processed video -> {output_path}")
# Out:
# ✅ Using codec mp4v, saving to output_videos/final_output.mp4
# ▶️ Processing video...
#
# 0: 320x640 (no detections), 54.6ms
# Speed: 8.8ms preprocess, 54.6ms inference, 90.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 3.8ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 4.0ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.6ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 3.7ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 1.8ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 3.3ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 209.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 2.7ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 4.2ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 5.8ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 5.2ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.7ms
# Speed: 5.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 2.5ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.5ms
# Speed: 1.8ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 4.8ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 1.9ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.3ms
# Speed: 3.1ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.4ms
# Speed: 2.2ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 smoking, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 4.6ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 2.8ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.0ms
# Speed: 3.1ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.9ms
# Speed: 3.4ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.9ms
# Speed: 3.5ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.2ms
# Speed: 3.3ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.2ms
# Speed: 3.4ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.9ms
# Speed: 3.2ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.7ms
# Speed: 3.4ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.2ms
# Speed: 2.9ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.4ms
# Speed: 7.0ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.1ms
# Speed: 2.8ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.2ms
# Speed: 2.7ms preprocess, 15.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.0ms
# Speed: 4.8ms preprocess, 8.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.6ms
# Speed: 1.7ms preprocess, 12.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 🎉 Done! Saved processed video -> output_videos/final_output.mp4

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install `moviepy` to handle audio and video merging.

# %% [markdown]
# **Reasoning**:
# Install the moviepy library using pip.

# %%
# %pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.8.3)

# %% [markdown]
# ## Process video frames
#
# ### Subtask:
# Use the existing code to process the video frames and save them as an intermediate video file without audio.

# %% [markdown]
# **Reasoning**:
# Modify the existing code to save the annotated video to a new intermediate file path, focusing only on the video frames without audio processing.

# %% [markdown]
# ## Extract audio
#
# ### Subtask:
# Extract the audio track from the original video file.

# %% [markdown]
# **Reasoning**:
# Extract the audio from the original video using moviepy and save it to a file.

# %%
from moviepy.editor import VideoFileClip
import os

# Define paths
input_video = "input.mp4"
output_folder = "output_videos"
audio_output_path = os.path.join(output_folder, "extracted_audio.wav")

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Load the original video clip
try:
    video_clip = VideoFileClip(input_video)
except Exception as e:
    print(f"❌ Error loading video file: {e}")
    video_clip = None


if video_clip is not None:
    # Extract the audio
    audio_clip = video_clip.audio

    if audio_clip is not None:
        # Write the audio to a file
        try:
            audio_clip.write_audiofile(audio_output_path, codec='pcm_s16le')
            print(f"✅ Successfully extracted audio to {audio_output_path}")
        except Exception as e:
            print(f"❌ Error writing audio file: {e}")
        finally:
            # Close the audio clip
            audio_clip.close()
    else:
        print("⚠️ No audio track found in the video.")

    # Close the video clip
    video_clip.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':
# MoviePy - Writing audio in output_videos/extracted_audio.wav
# MoviePy - Done.
# ✅ Successfully extracted audio to output_videos/extracted_audio.wav

# %% [markdown]
# ## Combine video and audio
#
# ### Subtask:
# Use `moviepy` to combine the intermediate video file (with detections) and the extracted audio track into a new video file.

# %% [markdown]
# **Reasoning**:
# Import necessary classes from moviepy, define file paths, load the intermediate video and extracted audio, combine them, write the final video, and close the clips.

# %%
from moviepy.editor import VideoFileClip, AudioFileClip
import os

# Define the paths
output_folder = "output_videos"
intermediate_video_path = os.path.join(output_folder, "final_output.mp4")
audio_path = os.path.join(output_folder, "extracted_audio.wav")
final_video_path = os.path.join(output_folder, "final_output_video_with_audio_done.mp4")

# Load the clips
try:
    video_clip = VideoFileClip(intermediate_video_path)
    audio_clip = AudioFileClip(audio_path)
except Exception as e:
    print(f"❌ Error loading video or audio clip: {e}")
    video_clip = None
    audio_clip = None

if video_clip is not None and audio_clip is not None:
    # Set the audio of the video clip
    final_clip = video_clip.set_audio(audio_clip)

    # Write the combined video file
    try:
        final_clip.write_videofile(final_video_path, codec='libx264', audio_codec='aac')
        print(f"✅ Successfully combined video and audio, saved to {final_video_path}")
    except Exception as e:
        print(f"❌ Error writing final video file: {e}")
    finally:
        # Close the clips
        video_clip.close()
        audio_clip.close()
        final_clip.close()
elif video_clip is not None:
    video_clip.close()
elif audio_clip is not None:
    audio_clip.close()
# Out:
# Moviepy - Building video output_videos/final_output_video_with_audio_done.mp4.
# MoviePy - Writing audio in final_output_video_with_audio_doneTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output_videos/final_output_video_with_audio_done.mp4
# Moviepy - Done !
# Moviepy - video ready output_videos/final_output_video_with_audio_done.mp4
# ✅ Successfully combined video and audio, saved to output_videos/final_output_video_with_audio_done.mp4

# %% [markdown]
# ## Clean up intermediate files
#
# ### Subtask:
# Remove the intermediate video file that was created in step 2.

# %% [markdown]
# **Reasoning**:
# Import the os module and remove the intermediate video file.

# %%
import os

# Define the path to the intermediate video file
output_folder = "output_videos"
intermediate_video_path = os.path.join(output_folder, "intermediate_output_video.mp4")

# Check if the intermediate video file exists and remove it
if os.path.exists(intermediate_video_path):
    try:
        os.remove(intermediate_video_path)
        print(f"✅ Successfully removed intermediate video file: {intermediate_video_path}")
    except OSError as e:
        print(f"❌ Error removing intermediate video file {intermediate_video_path}: {e}")
else:
    print(f"ℹ️ Intermediate video file not found: {intermediate_video_path}")
# Out:
# ✅ Successfully removed intermediate video file: output_videos/intermediate_output_video.mp4

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `moviepy` library was successfully installed (or confirmed as already installed) for handling audio and video.
# *   An intermediate video file (`intermediate_output_video.mp4`) was created containing the original video frames with animal detections and bounding boxes, but without audio.
# *   The original audio track was successfully extracted from the input video and saved as a WAV file (`extracted_audio.wav`).
# *   The intermediate video and the extracted audio were successfully combined into a final output video file (`final_output_video_with_audio.mp4`).
# *   The intermediate video file (`intermediate_output_video.mp4`) was successfully removed after the final video was created.
#
# ### Insights or Next Steps
#
# *   The process successfully demonstrates a workflow for performing object detection on a video and preserving the original audio in the output.
# *   Consider adding error handling for cases where no animals are detected in the video frames.
